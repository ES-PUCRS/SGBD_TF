# %% [markdown]
# ------------------------ HandBook ------------------------
# #     	Legenda do resumo
# # #!# 	= Atribuição ao X
# # #*# 	= Ação manual necessária
# # ###!	= Observações das escolhas no passo
# # #!	= Observação para a execução do passo
#
# ## 1. Importar bibliotecas
# import pandas as pd
# import matplotlib.pyplot as plt
# import scipy.stats as stats
# import numpy as np
# from sklearn.model_selection import train_test_split
# from sklearn.impute import SimpleImputer
# from sklearn.preprocessing import StandardScaler
# from sklearn.preprocessing import LabelBinarizer
#
# #*# 2. Importar dataset
# #! com pasta 'database/file.csv'
# file = '.csv'
# df = pd.read_csv(file)
#
# ## 3. Analise exploratória de dados
# df.info()
# df.head()
#
# #*# 3.1. Agrupando atributos (facilita a vida)
# atributos_X 		 = [] # preenchido no passo 5.5
# atributos_preditivos = [] # preenchido no passo 4
# atributo_alvo		 = ''
# atributos    		 = []
# atributos_numericos	 = []
# atributos_binarios	 = []
# atributos_nominais	 = []
# atributos_enum		 = []
#
# ## 4. Resolvendo valores ausentes
# atrb_na = []
# ###! Remove linha nula
# #df_treino.dropna(subset=atrb_na)
# ###! Remove coluna nula
# #df_treino.drop(atrib_na, axis=1)
# ###! Procura o valor para preencher linhas com valor nulo
# #! strategy : string, default='mean'
# #!    - If "mean", then replace missing values using the mean along
# #!      each column. Can only be used with numeric data.
# #!
# #!    - If "median", then replace missing values using the median along
# #!      each column. Can only be used with numeric data.
# #!	Use when the values are smoothly distributed
# #!
# #!    - If "most_frequent", then replace missing using the most frequent
# #!      value along each column. Can be used with strings or numeric data.
# #!
# #!    - If "constant", then replace missing values with fill_value. Can be
# #!      used with strings or numeric data.
# #estrategia	  = 'mean'
# #imputer = SimpleImputer(strategy='estrategia')
# #novos_valores = imputer.fit_transform(df_treino[atrb_na])
#
# ## 4.1. Calculando as correlações entre os atributos
# atributos_preditivos = atributos_numericos
# atributos_preditivos = np.append(atributos_preditivos, atributos_enum)
# corr = np.corrcoef(df[atributos_preditivos],rowvar=False)
# dfcorr = pd.DataFrame(corr,index=atributos_preditivos,columns=atributos_preditivos)
# dfcorr.to_csv('correlmat.csv',sep=';',decimal=',')
#
# #*# 4.2. Listando atributos desnecessários
# #! Atributo com valor muito próximos de 1 do passo acima.
# #! + Atributos irrelevantes para o aprendizado
# atributos_desnecessarios = []
#
# ## 5. Pré-processamento
# df_treino, df_teste = train_test_split(df, test_size=0.2, random_state=42)
#
# ## 5.1. Separando o atributo alvo dos preditivos
# df_treino_labels = df_treino[atributo_alvo].copy()
# df_treino        = df_treino.drop(columns=atributo_alvo)
#
# ## 5.2. (+> 4.1) Removendo atributos desnecessários
# df_treino = df_treino.drop (columns=atributos_desnecessarios)
# df_teste  = df_teste.drop  (columns=atributos_desnecessarios)
#
# #*# Resolvendo valores ausentes
# #! Antecipado ao passo 4 para poder exportar Pearson
#
# ## 5.3. Ajustando a escala dos atributos numéricos quantitativos
# scaler = StandardScaler()
# scaler.fit(df_treino[atributos_numericos])
#
# #!# 5.4. Populando o X_treino com colunas numericas
# X = scaler.transform(df_treino[atributos_numericos])
# atributos_X = atributos_numericos
#
# #!# 5.5. Populando o X_treino com colunas binárias
# X = np.concatenate((X, df_treino[atributos_binarios]),axis=1)
# atributos_X = np.append(atributos_X, atributos_binarios)
#
# #!# 5.6. Binarizando atributos categóricos
# for atrb_name in atributos_enum:
# 	# binarizando a coluna de nome atrb_name
# 	lb = LabelBinarizer()
# 	dados = lb.fit_transform(df_treino[atrb_name].values)
#
# 	# acrescentando a matriz com as novas colunas na matriz X
# 	X = np.concatenate((X, dados),axis=1)
#
# 	# criando nomes para as novas colunas no seguinte formato: nome_do_atributo=valor_do_atributo
# 	nomes_novos_atributos = []
# 	for class_name in lb.classes_:
# 		nomes_novos_atributos = np.append(nomes_novos_atributos,atrb_name+'='+str(class_name))
#
# 	# acrescentando os nomes das novas colunas na lista completa do dataset
# 	atributos_X = np.append(atributos_X, nomes_novos_atributos)
#
# 	# Debug da transformação de num para enum
# 	# print('Nome do atributo categórico: ',atrb_name)
# 	# print('Classes aprendidas: ',lb.classes_)
# 	# print('Nomes dos novos atributos: ',nomes_novos_atributos)
# 	# print("Primeiras 5 linhas dos dados: ")
# 	# print(dados[0:5,])
# 	# print()
#
# ## 6. Visualização do resultado do pré-processamento
# df_treino_preproc = pd.DataFrame(X, columns=atributos_X)
# df_treino_preproc.head()

# %% [markdown]
# # 1. Importando bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelBinarizer

# %% [markdown]
# # 2. Importando DataSet

# %%
#! com pasta 'database/file.csv'
datasetFolder = 'Dataset/'
file = datasetFolder + 'data.csv'
df = pd.read_csv(file)
dataset = df

# %% [markdown]
# ## 3. Primeira analise do dataset

# %%
## 3. Analise exploratória de dados
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11500 entries, 0 to 11499
# Columns: 180 entries, Unnamed: 0 to y
# dtypes: int64(179), object(1)
# memory usage: 15.8+ MB
#    Unnamed: 0   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  X171  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17   -15
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164   150
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57    64
# 3   X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82   -81
# 4   X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4     2
#
#    X172  X173  X174  X175  X176  X177  X178  y
# 0   -31   -77  -103  -127  -116   -83   -51  4
# 1   146   152   157   156   154   143   129  1
# 2    48    19   -12   -30   -35   -35   -36  5
# 3   -80   -77   -85   -77   -72   -69   -65  5
# 4   -12   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 180 columns]

# %% [markdown]
# # 3.1. Analise exploratória - Agrupando atributos

# %%
atributos_X          = [] # Preenchido no passo 5.5
atributos_preditivos = [] # Usado no passo 4

#Definindo os atributos
atributo_alvo        = 'y'
atributos_desnecessarios = ['Unnamed: 0']
atributos_numericos  = list( x for x in dataset.columns if x not in atributos_desnecessarios )
atributos_binarios   = []
atributos_nominais   = []
atributos_enum       = []

#Removendo o atributo alvo das variáveis de pesquisa
atributos_numericos  = [ x for x in atributos_numericos if x is not atributo_alvo ]
atributos_binarios   = [ x for x in atributos_binarios if x is not atributo_alvo ]
atributos_nominais   = [ x for x in atributos_nominais if x is not atributo_alvo ]
atributos_enum       = [ x for x in atributos_enum if x is not atributo_alvo ]

# Reunindo atributos
atributos            = atributos_numericos
atributos            = np.append(atributos, atributos_binarios)
atributos            = np.append(atributos, atributos_nominais)
atributos            = np.append(atributos, atributos_enum)

# %% [markdown]
# ## 4. Resolvendo valores ausentes e/ou desnecessários

# %%
# atrb_na = ['']2
###! Remove linha nula
# df = df.dropna(subset=atrb_na)
###! Remove coluna nula
df = df.drop(atributos_desnecessarios, axis=1)
###! Procura o valor para preencher linhas com valor nulo
#! strategy : string, default='mean'
#!    - If "mean", then replace missing values using the mean along
#!      each column. Can only be used with numeric data.
#!
#!    - If "median", then replace missing values using the median along
#!      each column. Can only be used with numeric data.
#!	Use when the values are smoothly distributed
#!
#!    - If "most_frequent", then replace missing using the most frequent
#!      value along each column. Can be used with strings or numeric data.
#!
#!    - If "constant", then replace missing values with fill_value. Can be
#!      used with strings or numeric data.
#estrategia	  = 'mean'
#imputer = SimpleImputer(strategy=estrategia)
#novos_valores = imputer.fit_transform(df_treino[atrb_na])

# %% [markdown]
# ## 4.1. Calculando as correlações entre os atributos

# %%
# Prepara os atributos não String
atributos_preditivos = atributos_numericos
atributos_preditivos = np.append(atributos_preditivos, atributos_enum)

print (
    'Quantidade de atributos preditivos: ',
        atributos_preditivos.size,
    '.\nLista dos atributos preditivos:',
        atributos_preditivos)

# Correlação de Pearson
corr = np.corrcoef(df[atributos_preditivos],rowvar=False)

# Tabularização das informações
dfcorr = pd.DataFrame(corr,index=atributos_preditivos,columns=atributos_preditivos)

# Exporta para csv
dfcorr.to_csv(datasetFolder + 'correlmat.csv',sep=';',decimal=',')
# Out:
# Quantidade de atributos preditivos:  178 .
# Lista dos atributos preditivos: ['X1' 'X2' 'X3' 'X4' 'X5' 'X6' 'X7' 'X8' 'X9' 'X10' 'X11' 'X12' 'X13'
#  'X14' 'X15' 'X16' 'X17' 'X18' 'X19' 'X20' 'X21' 'X22' 'X23' 'X24' 'X25'
#  'X26' 'X27' 'X28' 'X29' 'X30' 'X31' 'X32' 'X33' 'X34' 'X35' 'X36' 'X37'
#  'X38' 'X39' 'X40' 'X41' 'X42' 'X43' 'X44' 'X45' 'X46' 'X47' 'X48' 'X49'
#  'X50' 'X51' 'X52' 'X53' 'X54' 'X55' 'X56' 'X57' 'X58' 'X59' 'X60' 'X61'
#  'X62' 'X63' 'X64' 'X65' 'X66' 'X67' 'X68' 'X69' 'X70' 'X71' 'X72' 'X73'
#  'X74' 'X75' 'X76' 'X77' 'X78' 'X79' 'X80' 'X81' 'X82' 'X83' 'X84' 'X85'
#  'X86' 'X87' 'X88' 'X89' 'X90' 'X91' 'X92' 'X93' 'X94' 'X95' 'X96' 'X97'
#  'X98' 'X99' 'X100' 'X101' 'X102' 'X103' 'X104' 'X105' 'X106' 'X107'
#  'X108' 'X109' 'X110' 'X111' 'X112' 'X113' 'X114' 'X115' 'X116' 'X117'
#  'X118' 'X119' 'X120' 'X121' 'X122' 'X123' 'X124' 'X125' 'X126' 'X127'
#  'X128' 'X129' 'X130' 'X131' 'X132' 'X133' 'X134' 'X135' 'X136' 'X137'
#  'X138' 'X139' 'X140' 'X141' 'X142' 'X143' 'X144' 'X145' 'X146' 'X147'
#  'X148' 'X149' 'X150' 'X151' 'X152' 'X153' 'X154' 'X155' 'X156' 'X157'
#  'X158' 'X159' 'X160' 'X161' 'X162' 'X163' 'X164' 'X165' 'X166' 'X167'
#  'X168' 'X169' 'X170' 'X171' 'X172' 'X173' 'X174' 'X175' 'X176' 'X177'
#  'X178']

# %% [markdown]
# # 5. Pré-processamento

# %%
df_treino, df_teste = train_test_split(df, test_size=0.2, random_state=42)

# %% [markdown]
# ## 5.1. Separando o atributo alvo dos preditivos

# %%
df_treino_labels = df_treino[atributo_alvo].copy()
df_treino        = df_treino.drop(columns=atributo_alvo)

# %% [markdown]
# ## 5.3. Ajustando a escala dos atributos numéricos quantitativos

# %%
scaler = StandardScaler()
scaler.fit(df_treino[atributos_numericos])
# Out:
# StandardScaler()

# %% [markdown]
# ## 5.4. Populando o X_treino com colunas numericas

# %%
X = scaler.transform(df_treino[atributos_numericos])
atributos_X = atributos_numericos

# %% [markdown]
# ## 5.5. Populando o X_treino com colunas binárias

# %%
X = np.concatenate((X, df_treino[atributos_binarios]),axis=1)
atributos_X = np.append(atributos_X, atributos_binarios)

# %% [markdown]
# ## 5.6. Binarizando atributos categóricos

# %%
for atrb_name in atributos_enum:
    # binarizando a coluna de nome atrb_name
    lb = LabelBinarizer()
    dados = lb.fit_transform(df_treino[atrb_name].values)
    
    # acrescentando a matriz com as novas colunas na matriz X
    X = np.concatenate((X, dados),axis=1)
    
    # criando nomes para as novas colunas no seguinte formato: nome_do_atributo=valor_do_atributo
    nomes_novos_atributos = []
    for class_name in lb.classes_:
        nomes_novos_atributos = np.append(nomes_novos_atributos,atrb_name+'='+str(class_name))
        
    # acrescentando os nomes das novas colunas na lista completa do dataset
    atributos_X = np.append(atributos_X, nomes_novos_atributos)

# %%
X[0:2]
# Out:
# array([[-3.34457385e-01, -3.95090990e-01, -5.28236425e-01,
#         -6.91477583e-01, -8.25966141e-01, -9.79599275e-01,
#         -1.03794711e+00, -1.05876403e+00, -1.15756126e+00,
#         -1.49811159e+00, -1.93587961e+00, -2.37945719e+00,
#         -2.50205347e+00, -2.39537277e+00, -2.15250081e+00,
#         -1.84804412e+00, -1.60089736e+00, -1.26310824e+00,
#         -1.03941290e+00, -8.22327027e-01, -6.38733175e-01,
#         -4.69065154e-01, -3.16588999e-01, -2.74965962e-01,
#         -2.45348249e-01, -2.40978579e-01, -1.56651760e-01,
#         -4.54541662e-02,  1.70801375e-01,  3.75751627e-01,
#          5.43998655e-01,  6.53781407e-01,  6.49020654e-01,
#          5.56890332e-01,  4.40048891e-01,  3.31029466e-01,
#          2.33902253e-01,  1.39976785e-01, -1.74286793e-03,
#         -4.37557106e-01, -9.40258631e-01, -1.32260735e+00,
#         -1.38627540e+00, -1.13224760e+00, -7.97194328e-01,
#         -4.93888831e-01, -1.73119140e-01,  3.43412947e-02,
#          1.38283315e-01,  1.96612451e-01,  1.00338870e-01,
#          7.51047326e-03, -2.36843655e-01, -5.57457265e-01,
#         -8.38931671e-01, -1.03215638e+00, -9.78833844e-01,
#         -7.98930277e-01, -4.99972759e-01, -1.84817634e-01,
#          6.59701799e-02,  2.51343642e-01,  3.48041079e-01,
#          3.60331237e-01,  2.66222034e-01,  1.73362658e-01,
#          8.92807963e-02,  2.46254549e-02, -1.05863710e-02,
#         -1.53485360e-02, -1.38282607e-02, -3.94172629e-02,
#         -6.64141124e-03,  8.14433274e-02,  2.33935885e-01,
#          3.27311258e-01,  3.92372372e-01,  3.52171512e-01,
#          1.99970521e-01,  1.92880935e-02, -1.29776361e-01,
#         -2.43827125e-01, -3.78885509e-01, -4.69498631e-01,
#         -5.83116342e-01, -6.20689406e-01, -5.60299200e-01,
#         -3.97535980e-01, -2.18247926e-01, -3.77846809e-02,
#          7.59245811e-02,  8.33472190e-02, -2.45346827e-02,
#         -1.65709184e-01, -3.17272555e-01, -4.17509417e-01,
#         -5.23736137e-01, -5.99661996e-01, -6.70876326e-01,
#         -6.79866421e-01, -6.14112012e-01, -4.41956261e-01,
#         -2.38913762e-01, -4.22248028e-02,  1.35958956e-01,
#          2.38488743e-01,  2.12312040e-01,  6.29928240e-02,
#         -1.15738599e-01, -3.24760947e-01, -4.53421460e-01,
#         -5.37976778e-01, -5.46127840e-01, -4.73581347e-01,
#         -2.92654136e-01, -6.76992719e-02,  1.62860875e-01,
#          3.71616911e-01,  5.60722364e-01,  6.16768858e-01,
#          5.33756185e-01,  2.60013155e-01,  2.12087955e-02,
#         -1.96565245e-01, -3.58648621e-01, -7.32789004e-01,
#         -1.25097722e+00, -1.72898548e+00, -1.85758602e+00,
#         -1.71795155e+00, -1.41306248e+00, -1.10737369e+00,
#         -7.70268548e-01, -4.61038454e-01, -2.51302470e-01,
#         -9.33367785e-02, -2.74122654e-02, -6.43071777e-03,
#         -1.98197400e-02, -3.48358843e-03,  5.09500587e-02,
#          1.90151965e-01,  3.97323214e-01,  4.63985717e-01,
#          2.86470066e-01,  1.10177190e-01, -1.26710348e-01,
#         -1.60307583e-01, -1.67313990e-01, -7.89391177e-02,
#          5.90255844e-02,  1.69618978e-01,  1.72899241e-01,
#          1.22794050e-01,  4.32716438e-02,  6.89144393e-02,
#          2.28757343e-01,  4.41221861e-01,  5.51013565e-01,
#          3.30593094e-01,  6.73434058e-02, -2.59626961e-01,
#         -4.47662368e-01, -3.40643662e-01, -2.13476765e-01,
#         -6.33732903e-02,  3.63946275e-02,  4.71820383e-02,
#          9.09172476e-02,  2.17163879e-01,  3.69640531e-01,
#          5.62405543e-01,  7.15398714e-01,  8.84155535e-01,
#          9.45504819e-01,  5.63720349e-01, -1.12139896e-01,
#         -6.44244584e-01],
#        [-4.01371607e-01, -2.42612501e-01, -1.63239822e-01,
#         -3.92436237e-01, -7.26328841e-01, -8.16830268e-01,
#         -8.30442304e-01, -7.70811426e-01, -5.52081939e-01,
#         -2.01400711e-01, -7.76433287e-02, -7.59814955e-02,
#         -9.52112981e-02, -2.46965046e-01, -3.99237584e-01,
#         -4.16924043e-01, -3.73578515e-01, -4.09418294e-01,
#         -3.26931835e-01, -2.57769756e-01, -4.04152232e-01,
#         -5.42676738e-01, -5.40667346e-01, -4.44463679e-01,
#         -3.98184220e-01, -3.39917417e-01, -3.48198304e-01,
#         -5.79651576e-01, -8.13367135e-01, -7.69382932e-01,
#         -6.38880802e-01, -5.63000996e-01, -3.44012309e-01,
#         -1.80777905e-01, -1.76734803e-01, -2.98558140e-01,
#         -3.14951330e-01, -2.77842752e-01, -2.92506176e-01,
#         -2.17053874e-01, -1.69220776e-01, -2.60523262e-01,
#         -5.05430974e-01, -4.98724517e-01, -4.36951909e-01,
#         -4.69581945e-01, -4.69980363e-01, -5.28757493e-01,
#         -5.99523271e-01, -6.19027855e-01, -3.32147576e-01,
#         -1.22801465e-01, -1.69012217e-01, -2.09867972e-01,
#         -2.61568121e-01, -4.60136840e-01, -7.17383961e-01,
#         -6.92700568e-01, -5.90531722e-01, -5.16085729e-01,
#         -3.55637928e-01, -1.28639703e-01,  1.03710090e-02,
#          1.50851906e-01,  3.03102017e-01,  2.10297446e-01,
#         -8.49111217e-02, -3.27488957e-01, -4.92521031e-01,
#         -6.68084669e-01, -7.96291301e-01, -6.86155493e-01,
#         -5.66410815e-01, -4.19009081e-01, -1.27318884e-01,
#          1.97020942e-01,  1.71482089e-01, -7.99921913e-03,
#         -2.24622251e-01, -5.21355247e-01, -6.38421149e-01,
#         -5.68912509e-01, -4.39984292e-01, -4.00528980e-01,
#         -4.62372733e-01, -5.89073512e-01, -8.33949603e-01,
#         -1.12795855e+00, -1.18270440e+00, -1.17013465e+00,
#         -1.13433695e+00, -9.98927054e-01, -7.83707707e-01,
#         -5.71060020e-01, -3.60901130e-01, -8.80176712e-02,
#          3.68961939e-02, -1.36909285e-01, -3.30901601e-01,
#         -5.26107207e-01, -8.77359556e-01, -1.04515657e+00,
#         -9.45337045e-01, -7.71114218e-01, -6.07571675e-01,
#         -4.34071168e-01, -3.12510121e-01, -2.95928381e-01,
#         -4.51616846e-01, -5.51587921e-01, -6.44128741e-01,
#         -8.98833346e-01, -1.00123380e+00, -8.02179673e-01,
#         -4.66007028e-01, -2.96627510e-01, -1.58545319e-01,
#         -1.95080970e-01, -4.51635728e-01, -7.12374311e-01,
#         -8.10907989e-01, -7.86738452e-01, -6.87966119e-01,
#         -5.27906290e-01, -4.88620064e-01, -5.88866267e-01,
#         -5.86644559e-01, -4.36754086e-01, -3.48189256e-01,
#         -4.10739266e-01, -4.88813578e-01, -6.55961269e-01,
#         -7.70268548e-01, -6.60497257e-01, -3.50085890e-01,
#         -1.48359207e-01, -7.00669611e-02,  2.39870732e-02,
#         -5.61838180e-02, -2.07693945e-01, -3.00764810e-01,
#         -3.35486977e-01, -5.06003945e-01, -6.40878865e-01,
#         -6.10706227e-01, -6.26511802e-01, -6.60403243e-01,
#         -7.20518206e-01, -7.31809326e-01, -7.23179805e-01,
#         -5.47304600e-01, -1.19112362e-01,  5.59271253e-02,
#         -1.96479778e-01, -4.81792776e-01, -7.51283286e-01,
#         -1.01818140e+00, -9.98795813e-01, -7.63958474e-01,
#         -6.68005570e-01, -6.98408150e-01, -6.70088578e-01,
#         -5.69023697e-01, -4.72351733e-01, -2.78810523e-01,
#         -6.93498189e-02,  3.03816873e-02, -8.49472533e-02,
#         -2.34833985e-01, -3.77106795e-01, -4.99646440e-01,
#         -5.27478250e-01, -3.75981730e-01, -1.23814096e-01,
#          1.44686683e-01,  4.54115762e-01,  5.42375184e-01,
#          3.72489300e-01]])

# %% [markdown]
# ## 6. Visualização do resultado do pré-processamento

# %%
df_treino_preproc = pd.DataFrame(X, columns=atributos_X)
df_treino_preproc.head()
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0 -0.334457 -0.395091 -0.528236 -0.691478 -0.825966 -0.979599 -1.037947
# 1 -0.401372 -0.242613 -0.163240 -0.392436 -0.726329 -0.816830 -0.830442
# 2 -0.383122 -0.346298 -0.299340 -0.261606 -0.215688 -0.128192 -0.101031
# 3  0.170441  0.184327  0.207943  0.236797  0.263817  0.259949  0.276250
# 4  0.255604  0.245319  0.337857  0.429927  0.176634  0.141003  0.093897
#
#          X8        X9       X10  ...      X169      X170      X171      X172  \
# 0 -1.058764 -1.157561 -1.498112  ...  0.090917  0.217164  0.369641  0.562406
# 1 -0.770811 -0.552082 -0.201401  ... -0.234834 -0.377107 -0.499646 -0.527478
# 2 -0.082229 -0.077686 -0.132159  ...  0.187436  0.138332  0.140245  0.157421
# 3  0.274582  0.246901  0.220345  ...  0.489058  0.490043  0.508485  0.502849
# 4  0.130605  0.022187 -0.094391  ... -0.186575  0.289932  0.387751  0.508805
#
#        X173      X174      X175      X176      X177      X178
# 0  0.715399  0.884156  0.945505  0.563720 -0.112140 -0.644245
# 1 -0.375982 -0.123814  0.144687  0.454116  0.542375  0.372489
# 2  0.256184  0.332172  0.417693  0.484561  0.524024  0.501112
# 3  0.506665  0.548166  0.569363  0.575899  0.566843  0.494987
# 4  0.405280  0.524166  0.405559  0.137480 -0.020385 -0.399248
#
# [5 rows x 178 columns]
